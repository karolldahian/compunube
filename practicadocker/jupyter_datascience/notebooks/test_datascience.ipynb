# %% [markdown]
# # Prueba de Contenedor Docker para Data Science e IA
# Verificación de librerías en contenedor Ubuntu/Python.

# %%
import numpy as np
import pandas as pd
import sklearn
print('NumPy versión:', np.__version__)
print('Pandas versión:', pd.__version__)
print('Scikit-learn versión:', sklearn.__version__)
print('¡Entorno de Data Science funcionando en Docker con éxito!')
